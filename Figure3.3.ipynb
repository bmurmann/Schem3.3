# %%
import schemdraw
import schemdraw.elements as elm

# %%
with schemdraw.Drawing() as d:
   elm.SourceV().up().length(4).label('$V_{in}$')
   elm.Resistor().right().label('$R$')
   elm.Dot()
   d.push()
   elm.Line().right().dot(open=True).length(2)
   elm.Gap().down().label(['+', '$V_{out}$', '-']).length(4)
   d.pop()
   elm.Resistor().down().length(2).label('$R$', loc='bot')
   elm.Capacitor().down().length(2).label('$C$', loc='bot')
   elm.Dot()
   d.push()
   elm.Line().right().dot(open=True).length(2)
   d.pop()
   elm.Line().left()
