# %%
import schemdraw
import schemdraw.elements as elm

# %%
d = schemdraw.Drawing()

d += elm.SourceV().up().length(4).label('Vin')
d += elm.Resistor().right().label('R')
d += elm.Dot()

d += elm.Resistor().down().length(2).label('R')
d += elm.Capacitor().down().length(2).label('C', loc='bottom')
d += elm.Dot()
d += elm.Line().left()

d
